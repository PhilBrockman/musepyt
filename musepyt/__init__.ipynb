# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/repos/MusicalPy")

# %%
cd midimusic
# Out:
# /content/drive/My Drive/repos/MusicalPy/midimusic

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/repos/MusicalPy/midimusic/.git/

# %%
# !git remote add origin git@github.com:PhilBrockman/musepyt.git

# %%
# !git branch -M maine
# Out:
# error: refname refs/heads/master not found
# fatal: Branch rename failed

# %%
# !git submodule init

# %%
# !git submodule update

# %%
cat .gitmodules
# Out:
# cat: .gitmodules: No such file or directory

# %%
cat midimusic/.git
# Out:
# cat: midimusic/.git: No such file or directory

# %%
# !cd ..

# %%
ls
# Out:
# analyzers/        helpers/        __init__.py
# api_interaction/  __init__.ipynb  __pycache__/

# %%
# !git config --global user.email "phil.brockman@gmail.com"
# !git config --global user.name "Phil Brockman"

# %%
# !git add *

# %%
# !git commit  -m "been a minute"

# %%
# !git push --set-upstream origin master
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git remote set-url origin git@github.com:PhilBrockman/musepyt.git

# %%
# !eval "$(ssh-agent -s)"
# Out:
# Agent pid 872
